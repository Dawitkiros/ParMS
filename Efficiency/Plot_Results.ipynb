# %%
import matplotlib.pyplot as plt

# Data from the table
models = ["N=1", "N=2", "N=3", "N=4", "N=5"]
total_params = [6.57537, 3.289929, 2.19179, 1.644965, 1.315972]
he_time = [23.05, 12.28, 8.78, 6.68, 4.51]
cipher_text_size = [512.3, 256.3, 170.9, 128.1, 102.6]

# Create the subplots
fig, axes = plt.subplots(1, 2, figsize=(14, 6), dpi = 300)

# Plot 1: Number of Parameters vs Ciphertext Size
axes[0].plot(total_params, cipher_text_size, marker='o', linestyle='-', color='red', linewidth=2)
for i, model in enumerate(models):
    axes[0].annotate(model, (total_params[i], cipher_text_size[i]), textcoords="offset points", xytext=(-3,10), ha='center', fontsize=12)
axes[0].set_xlabel("Number of Parameters (10⁶)", fontsize=18)
axes[0].set_ylabel("Ciphertext Size (MB)", fontsize=18)
axes[0].tick_params(axis='both', labelsize=18)  # Adjust tick font size
axes[0].grid(True)

# Plot 2: Number of Parameters vs HE Time
axes[1].plot(total_params, he_time, marker='s', linestyle='-', color='blue', linewidth=2)
for i, model in enumerate(models):
    axes[1].annotate(model, (total_params[i], he_time[i]), textcoords="offset points", xytext=(-5,10), ha='center', fontsize=12)
axes[1].set_xlabel("Number of Parameters (10⁶)", fontsize=18)
axes[1].set_ylabel("HE Time (s)", fontsize=18)
axes[1].tick_params(axis='both', labelsize=18)  # Adjust tick font size
axes[1].grid(True)

# Adjust the layout
plt.tight_layout()
plt.savefig('he_plot.pdf', format='pdf')
plt.savefig('he_plot.svg', format='svg')

# Show the plot
plt.show()

# %%
[i/(10**6) for i in [6575370, 3289929, 2191790, 1644965, 1315972]]
# Out:
# [6.57537, 3.289929, 2.19179, 1.644965, 1.315972]

# %%
6575370/(10^6)
# Out:
# 547947.5

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data
rounds = np.arange(1, 51)  # Rounds from 1 to 50
efficiency_6 = [12.92, 11.23, 11.6, 11.62, 12.52, 13.57, 13.68, 13.7, 13.75, 13.46, 12.67, 14.1, 15.98, 16.01, 16.05, 16.01, 16.22, 16.1, 16.16, 26.36, 36.1, 37.72, 44.96, 45.08, 45.09, 45.22, 48.99, 49.33, 50.05, 53.62, 59.87, 68.93, 71.08, 72.26, 72.94, 74.02, 74.44, 76.16, 77.14, 79.4, 78.73, 81.46, 82.0, 82.37, 82.3, 82.66, 83.0, 83.19, 83.27, 83.82]
efficiency_10 = [11.32,
 10.0,
 10.0,
 10.0,
 10.0,
 10.34,
 13.63,
 11.25,
 10.0,
 10.0,
 10.0,
 12.21,
 12.21,
 12.22,
 12.24,
 12.24,
 12.29,
 10.25,
 10.06,
 12.39,
 13.33,
 13.33,
 13.33,
 13.33,
 13.33,
 13.35,
 11.46,
 17.97,
 21.71,
 33.01,
 32.99,
 32.87,
 33.69,
 34.15,
 35.41,
 43.04,
 55.58,
 54.88,
 62.43,
 62.67,
 62.83,
 64.2,
 64.36,
 64.59,
 66.68,
 67.6,
 67.91,
 68.8,
 68.8,
 68.9]
efficiency_8 = [15.96,
 12.28,
 14.73,
 14.92,
 15.67,
 16.21,
 15.36,
 9.09,
 10.55,
 15.17,
 11.83,
 11.83,
 11.83,
 11.82,
 12.3,
 11.14,
 13.81,
 17.52,
 15.31,
 15.31,
 74.44,
 77.39,
 79.13,
 79.98,
 80.91,
 83.23,
 83.64,
 84.46,
 84.5,
 85.8,
 85.62,
 85.94,
 86.1,
 86.34,
 86.45,
 86.62,
 86.75,
 87.03,
 87.14,
 87.24,
 87.22,
 87.17,
 87.18,
 87.13]
efficiency_33 = [12.11,
 14.12,
 15.91,
 25.39,
 25.67,
 26.87,
 46.16,
 49.8,
 57.0,
 63.15,
 65.28,
 68.37,
 70.81,
 72.51,
 74.39,
 76.55,
 76.77,
 77.85,
 79.84,
 79.88,
 80.51,
 81.44,
 81.7,
 82.74,
 83.76,
 83.71,
 84.68,
 85.1,
 85.74,
 85.78,
 86.6,
 85.72,
 86.01,
 86.52,
 86.8,
 87.29,
 87.42,
 87.39,
 87.26,
 88.1,
 88.21,
 88.49,
 88.26,
 88.4,
 88.69,
 89.24,
 89.19,
 88.98,
 89.08,
 89.09]
efficiency_3 = [11.87, 17.29, 12.79, 46.55, 43.55, 56.86, 57.53, 62.34, 60.08, 63.87, 75.78, 61.75, 69.33, 84.83, 81.09, 86.78, 83.82, 84.5, 74.83, 79.52, 76.83, 71.79, 88.03, 86.29, 87.91, 89.95, 89.32, 89.16, 89.25, 88.49, 89.68, 90.12, 89.28, 85.04, 87.48, 90.1, 90.22, 89.82, 88.62, 89.91, 88.91, 88.33, 88.32, 90.19, 86.02, 89.99, 88.97, 90.31, 89.78, 90.27]
efficiency_50 = [13.46, 13.09, 27.2, 26.89, 44.77, 56.43, 64.66, 70.34, 74.16, 77.56, 80.17, 81.58, 83.09, 84.21, 85.45, 85.7, 86.19, 86.92, 86.7, 86.65, 87.86, 88.2, 88.3, 88.15, 88.68, 89.36, 89.87, 90.17, 90.16, 90.13, 90.13, 90.11, 90.17, 90.14, 90.13, 90.22, 90.34, 90.24, 90.23, 90.27, 90.24, 90.1, 90.38, 90.3, 90.17, 90.28, 90.13, 90.12, 90.3, 90.27]
efficiency_100 = [11.42, 34.24, 51.78, 63.17, 71.37, 75.57, 80.48, 81.42, 82.99, 84.33, 85.69, 86.08, 86.39, 86.89, 87.19, 88.16, 87.79, 88.6, 88.61, 88.82, 88.88, 89.28, 89.39, 89.2, 89.79, 89.82, 90.05, 90.02, 89.8, 89.87, 90.26, 90.48, 90.57, 90.52, 90.44, 90.65, 90.35, 90.65, 90.87, 90.9, 91.23, 90.79, 90.94, 90.99, 91.26, 91.16, 91.55, 91.38, 91.24, 91.63]
efficiency_central = [44.59,
 56.56,
 72.96,
 74.9,
 81.46,
 84.46,
 85.96,
 85.09,
 86.24,
 86.39,
 87.3,
 87.05,
 87.62,
 87.11,
 87.21,
 88.94,
 89.04,
 89.22,
89.62,
 88.34,
 89.39,
 89.34,
 89.28,
 89.16,
 89.81,
 89.82,
 90.77,
 90.88,
 90.34,
 90.51,
 90.2,
 90.35,
 90.6,
 90.02,
 90.53,
 90.7,
 90.7,
 90.93, 90.86,
 90.55, 91.35, 91.98, 92.03, 91.34, 91.68,
 91.91,
 91.79,
 91.81,
 91.82,
 91.99]

efficiency_33_rnd = [22.91, 34.86, 35.17, 35.38, 47.84, 49.85, 69.45, 55.03, 72.5, 77.56, 78.94, 62.95, 73.03, 75.36, 80.69, 77.24, 76.48, 71.82, 77.75, 72.17, 75.69, 86.03, 82.18, 77.06, 78.61, 79.79, 82.58, 84.38, 89.69, 88.66, 88.9, 90.56, 90.04, 90.04, 90.31, 90.4, 89.28, 89.96, 90.23, 90.13, 89.42, 90.19, 89.66, 88.82, 89.56, 89.31, 90.14, 90.96, 90.24, 90.35]
efficiency_33_ls = [30.98,
 35.13666666666666,
 39.46333333333334,
 44.35666666666666,
 55.71333333333333,
 58.11000000000001,
 65.66000000000001,
 68.36333333333333,
 76.33333333333333,
 73.14999999999999,
 71.64,
 70.44666666666667,
 76.36,
 77.76333333333334,
 78.13666666666667,
 75.17999999999999,
 75.35000000000001,
 73.91333333333334,
 75.20333333333333,
 77.96333333333334,
 81.3,
 81.75666666666667,
 79.28333333333335,
 78.48666666666668,
 80.32666666666667,
 82.25,
 85.55,
 87.57666666666667,
 89.08333333333333,
 89.37333333333333,
 89.83333333333333,
 90.21333333333335,
 90.13,
 90.25,
 89.99666666666667,
 89.88,
 89.82333333333334,
 90.10666666666667,
 89.92666666666668,
 89.91333333333334,
 89.75666666666666,
 89.55666666666666,
 89.34666666666665,
 89.23,
 89.67,
 90.13666666666666,
 90.44666666666666,
 90.51666666666665,
 90.51666666666665,
 90.51666666666665]

efficiency_13 = [10.0, 27.67, 42.65, 38.58, 42.01, 53.59, 65.07, 59.19, 60.16, 78.65, 69.43, 76.09, 67.74, 72.26, 75.8, 78.61, 79.71, 81.37, 79.92, 76.92, 81.95, 73.98, 71.29, 75.42, 76.56, 80.36, 83.37, 84.49, 83.85, 87.76, 90.36, 89.18, 89.1, 89.52, 88.1, 88.51, 88.86, 89.88, 89.16, 90.32, 89.91, 90.1, 89.49, 88.31, 88.14, 88.58, 89.97, 88.3, 89.72, 90.04]

# Plotting the data
plt.figure(figsize=(14, 8), dpi=300)  # Increased figure size for better readability

# Plot each parameter sharing strategy
plt.plot(rounds, efficiency_5, marker='o', linestyle='-', color='orange', label='ParMS (N=5)',  markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)
plt.plot(rounds, efficiency_4, marker='X', linestyle='-', color='brown', label='ParMS (N=4)',  markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)
plt.plot(rounds, efficiency_33, marker='s', linestyle='-', color='m', label='ParMS (N=3)',  markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)
# plt.plot(rounds, avg_res, marker='X', linestyle='-', color='k', label='FL with random ma 4 partial sharing(N=3)',  markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)
# plt.plot(rounds, efficiency_33_rnd, marker='s', linestyle='-', color='orange', label='FL with random - 2 partial sharing(N=3)',  markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)
# plt.plot(rounds, efficiency_33_ls, marker='s', linestyle='-', color='brown', label='FL with random - ma partial sharing(N=3)',  markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)
# plt.plot(rounds, efficiency_3, marker='s', linestyle='-', color='k', label='FL with random partial sharing(N=3)',  markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)
plt.plot(rounds, efficiency_50, marker='d', linestyle='-', color='#e41a1c', label='ParMS (N=2)', markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)
plt.plot(rounds, efficiency_100, marker='^', linestyle='-', color='#4daf4a', label='FL (N=1)',  markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)
plt.plot(rounds, efficiency_central, marker='*', linestyle='-', color='#377eb8', label='Centralized training',  markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)

plt.style.use('seaborn-v0_8-darkgrid')
plt.rc('mathtext', fontset='cm')
plt.rc('font', size=22)

plt.ylabel("Test accuracy", fontsize=22)
plt.xlabel("Number of rounds", fontsize=22)
plt.legend(fontsize=22)
plt.grid(True)
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)
plt.tight_layout()

plt.savefig('test_acc_plot.pdf', format='pdf')
plt.savefig('test_acc_round_plot.svg', format='svg')
plt.show()

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
import matplotlib.pyplot as plt
import numpy as np
rounds = np.arange(1, 51)  # Rounds from 1 to 50


loss_5 = [2.3456,
 2.2977,
 2.2727,
 2.25506,
 2.132268,
 2.09509,
 1.90788,
 1.8714,
 1.7853,
 1.6469,
 1.2982,
 1.2724,
 1.1943,
 1.0719,
 0.9988,
 0.9599,
 0.8561,
 0.8087,
 0.7964,
 0.7622,
 0.6967,
 0.6495,
 0.6255,
 0.6002,
 0.5985,
 0.5842,
 0.5796,
 0.5721,
 0.5609,
 0.559,
 0.5541,
 0.5445,
 0.5421,
 0.5382,
 0.5384,
 0.531,
 0.5249,
 0.5109,
 0.5049,
 0.4957,
 0.4917,
 0.4903,
 0.4883,
 0.4849,
 0.4832,
 0.4801,
 0.4795,
 0.4784,
 0.4729,
 0.4669]
loss_4 = [2.3869,
 2.295,
 2.2873,
 2.05227,
 2.00163,
 1.9223,
 1.82727,
 1.7558,
 1.2959,
 1.1207,
 1.0553,
 1.0081,
 0.9911,
 0.9458,
 0.83328,
 0.7975,
 0.7817,
 0.74231,
 0.7082,
 0.68951,
 0.65524,
 0.62076,
 0.592123,
 0.5886,
 0.5716,
 0.5685,
 0.5501,
 0.5495,
 0.53187,
 0.53092,
 0.5294,
 0.5200,
 0.5199,
 0.5105,
 0.5096,
 0.5079,
 0.5049,
 0.500,
 0.4949,
 0.4807,
 0.4797,
 0.4753,
 0.4703,
 0.4699,
 0.4652,
 0.4601,
 0.4595,
 0.4584,
 0.4529,
 0.4509]
loss_33 = [2.3079,
 2.2837,
 2.173,
 1.9674,
 1.7656,
 1.3106,
 1.1133,
 1.0087,
 0.99101,
 0.9008,
 0.89496,
 0.7546,
 0.7201,
 0.7075,
 0.69594,
 0.6529,
 0.6431,
 0.6372,
 0.6269,
 0.60005,
 0.59838,
 0.580524,
 0.560457,
 0.550173,
 0.5431,
 0.5391,
 0.5258,
 0.5143,
 0.5065,
 0.4905,
 0.4867,
 0.4804,
 0.4799,
 0.4783,
 0.4701,
 0.4695,
 0.4646,
 0.4595,
 0.4559,
 0.4464,
 0.4483,
 0.4438,
 0.4401,
 0.4387,
 0.4315,
 0.4293,
 0.4272,
 0.4228,
 0.4183,
 0.4136]
loss_50 = [2.2794,
 2.2519,
 1.8013,
 1.7433,
 1.5277,
 1.2282,
 1.0157,
 0.9831,
 0.8085,
 0.7985,
 0.6774,
 0.6224,
 0.6032,
 0.586,
 0.543,
 0.5367,
 0.5219,
 0.5193,
 0.5131,
 0.4928,
 0.4763,
 0.4576,
 0.4419,
 0.4325,
 0.4318,
 0.4321,
 0.4293,
 0.421,
 0.4165,
 0.4109,
 0.4098,
 0.4089,
 0.4072,
 0.4031,
 0.4004,
 0.3941,
 0.3934,
 0.3931,
 0.3829,
 0.3825,
 0.3823,
 0.3719,
 0.3715,
 0.3713,
 0.3712,
 0.3612,
 0.3611,
 0.3610,
 0.3609,
 0.3609]
loss_100 = [2.2872,
 2.1022,
 1.6624,
 1.4577,
 1.2236,
 1.11414,
 0.9819,
 0.8467,
 0.7574,
 0.598,
 0.54,
 0.5064,
 0.4981,
 0.4705,
 0.4416,
 0.4369,
 0.4299,
 0.4296,
 0.4149,
 0.4199,
 0.4145,
 0.4131,
 0.4089,
 0.4041,
 0.4008,
 0.3906,
 0.3902,
 0.3801,
 0.3809,
 0.3789,
 0.3779,
 0.3666,
 0.363,
 0.3593,
 0.3589,
 0.357,
 0.3544,
 0.3412,
 0.3395,
 0.3249,
 0.32286,
 0.3283,
 0.3208,
 0.319,
 0.3164,
 0.3154,
 0.3167,
 0.31937,
 0.3195,
 0.31922]
loss_central = fl_loss = [1.7460764400482176, 1.4440922925949096, 0.5770800358772278, 0.47372434887886045, 0.4365600778102875, 0.3931789845943451, 0.3642325663089752, 0.3587616772651672, 0.348760612821579, 0.33131017439365384, 0.3406070181846619, 0.3409435050010681, 0.31629624338150025, 0.3248197310447693, 0.32302701659202576, 
           0.3262625814437866, 0.32419000968933104, 0.31497715601921084, 0.3205320776462555, 0.30374030122756956, 0.3158591908931732, 0.3135967821598053, 0.31723053441047666, 0.3261755410194397, 0.3155578875541687, 0.32434255714416504, 0.32406520295143126, 0.3275811056137085, 0.32356212139129636, 
           0.3134390698909759, 0.3158142679691315, 0.31074276962280275, 0.304874122428894, 0.3036338716506958, 0.30395611947059631, 0.30103010740280153, 0.3000342753930091857, 
           0.2935119930744171, 0.2817876832008362, 0.2911091980934146, 0.2833035600185394, 0.2867006880760193, 0.2933505478858948, 0.2959288251399994, 0.2929710032463074, 0.29097500858306887, 0.2964541922569275, 0.2931268483161926, 0.2953838870048523, 0.2919678658485413]

# Plotting the data
plt.figure(figsize=(14, 8), dpi=300)  # Increased figure size for better readability

# Plot each parameter sharing strategy
plt.plot(rounds, loss_5, marker='o', linestyle='-', color='orange', label='ParMS (N=5)',  markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)
plt.plot(rounds, loss_4, marker='X', linestyle='-', color='brown', label='ParMS (N=4)',  markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)
plt.plot(rounds, loss_33, marker='s', linestyle='-', color='m', label='ParMS (N=3)',  markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)
plt.plot(rounds, loss_50, marker='d', linestyle='-', color='#e41a1c', label='ParMS (N=2)', markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)
plt.plot(rounds, loss_100, marker='^', linestyle='-', color='#4daf4a', label='FL (N=1)',  markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)
plt.plot(rounds, loss_central, marker='*', linestyle='-', color='#377eb8', label='Centralized training',  markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)


plt.style.use('seaborn-v0_8-darkgrid')
plt.rc('mathtext', fontset='cm')
plt.rc('font', size=22)

plt.ylabel("Test loss", fontsize=22)
plt.xlabel("Number of rounds", fontsize=22)
plt.legend(fontsize=22)
plt.grid(True)
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)

plt.tight_layout()

plt.savefig('test_loss_plot.pdf', format='pdf')
plt.savefig('test_loss_round_plot.svg', format='svg')
plt.show()

# %%
# Create the subplots
fig, axes = plt.subplots(1, 2, figsize=(14, 6), dpi = 300)

# Plot 1:Efficiency vs number of rounds
axes[0].plot(rounds, efficiency_5, marker='o', linestyle='-', color='orange', label='FL with partial sharing(N=5)',  markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)
axes[0].plot(rounds, efficiency_4, marker='X', linestyle='-', color='brown', label='FL with partial sharing(N=4)',  markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)
axes[0].plot(rounds, efficiency_33, marker='s', linestyle='-', color='m', label='FL with partial sharing(N=3)',  markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)
# axes[0].plot(rounds, efficiency_3, marker='s', linestyle='-', color='k', label='FL with random partial sharing(N=3)',  markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)
axes[0].plot(rounds, efficiency_50, marker='d', linestyle='-', color='#e41a1c', label='FL with partial sharing(N=2)', markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)
axes[0].plot(rounds, efficiency_100, marker='^', linestyle='-', color='#4daf4a', label='Conventional FL',  markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)
axes[0].plot(rounds, efficiency_central, marker='*', linestyle='-', color='#377eb8', label='Centralized training',  markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)


axes[0].set_ylabel("Test Accuracy", fontsize=18)
axes[0].set_xlabel("Number of Rounds", fontsize=18)
axes[0].legend(fontsize=16)
axes[0].tick_params(axis='both', labelsize=18)
axes[0].grid(True)

# Plot 2: Test loss vs number of rounds
# axes[1].plot(total_params, he_time, marker='s', linestyle='-', color='blue', linewidth=2)
axes[1].plot(rounds, loss_5, marker='o', linestyle='-', color='orange', label='FL with partial sharing(N=5)',  markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)
axes[1].plot(rounds, loss_4, marker='X', linestyle='-', color='brown', label='FL with partial sharing(N=4)',  markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)
axes[1].plot(rounds, loss_33, marker='s', linestyle='-', color='m', label='FL with partial sharing(N=3)',  markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)
axes[1].plot(rounds, loss_50, marker='d', linestyle='-', color='#e41a1c', label='FL with partial sharing(N=2)', markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)
axes[1].plot(rounds, loss_100, marker='^', linestyle='-', color='#4daf4a', label='Conventional FL',  markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)
axes[1].plot(rounds, loss_central, marker='*', linestyle='-', color='#377eb8', label='Centralized training',  markevery=[0] + list(range(4, len(rounds), 5)), linewidth=2)

axes[1].set_ylabel("Test Loss", fontsize=18)
axes[1].set_xlabel("Number of Rounds", fontsize=18)
axes[1].legend(fontsize=16)
axes[1].tick_params(axis='both', labelsize=18)
axes[1].grid(True)

# Adjust the layout
plt.tight_layout()
plt.savefig('efficiency_plot.pdf', format='pdf')
plt.savefig('efficiency_plot.svg', format='svg')

# Show the plot
plt.show()

# %%
log_data = """ 100%|██████████| 10/10 [00:37<00:00,  3.74s/it]
100%|██████████| 10/10 [00:32<00:00,  3.26s/it]
100%|██████████| 10/10 [00:33<00:00,  3.33s/it]
100%|██████████| 10/10 [00:26<00:00,  2.68s/it]
100%|██████████| 10/10 [00:26<00:00,  2.63s/it]
100%|██████████| 10/10 [00:21<00:00,  2.14s/it]
100%|██████████| 10/10 [00:12<00:00,  1.23s/it]
100%|██████████| 10/10 [00:41<00:00,  4.17s/it]
100%|██████████| 10/10 [00:26<00:00,  2.67s/it]
100%|██████████| 10/10 [00:15<00:00,  1.60s/it]
Round 1, Train loss: 0.8460, Test Loss: 2.3772, Test Accuracy: 11.22%
100%|██████████| 10/10 [00:26<00:00,  2.64s/it]
100%|██████████| 10/10 [00:16<00:00,  1.61s/it]
100%|██████████| 10/10 [00:32<00:00,  3.25s/it]
100%|██████████| 10/10 [00:33<00:00,  3.33s/it]
100%|██████████| 10/10 [00:12<00:00,  1.22s/it]
100%|██████████| 10/10 [00:37<00:00,  3.73s/it]
100%|██████████| 10/10 [00:26<00:00,  2.63s/it]
100%|██████████| 10/10 [00:26<00:00,  2.67s/it]
100%|██████████| 10/10 [00:21<00:00,  2.14s/it]
100%|██████████| 10/10 [00:41<00:00,  4.16s/it]
Round 2, Train loss: 0.6415, Test Loss: 2.1022, Test Accuracy: 32.03%
100%|██████████| 10/10 [00:33<00:00,  3.33s/it]
100%|██████████| 10/10 [00:26<00:00,  2.63s/it]
100%|██████████| 10/10 [00:37<00:00,  3.72s/it]
100%|██████████| 10/10 [00:26<00:00,  2.66s/it]
100%|██████████| 10/10 [00:21<00:00,  2.13s/it]
100%|██████████| 10/10 [00:16<00:00,  1.61s/it]
100%|██████████| 10/10 [00:12<00:00,  1.23s/it]
100%|██████████| 10/10 [00:32<00:00,  3.26s/it]
100%|██████████| 10/10 [00:41<00:00,  4.15s/it]
100%|██████████| 10/10 [00:26<00:00,  2.65s/it]
Round 3, Train loss: 0.4768, Test Loss: 2.2624, Test Accuracy: 40.61%
100%|██████████| 10/10 [00:21<00:00,  2.13s/it]
100%|██████████| 10/10 [00:41<00:00,  4.15s/it]
100%|██████████| 10/10 [00:33<00:00,  3.32s/it]
100%|██████████| 10/10 [00:26<00:00,  2.67s/it]
100%|██████████| 10/10 [00:16<00:00,  1.61s/it]
100%|██████████| 10/10 [00:26<00:00,  2.63s/it]
100%|██████████| 10/10 [00:37<00:00,  3.73s/it]
100%|██████████| 10/10 [00:12<00:00,  1.23s/it]
100%|██████████| 10/10 [00:26<00:00,  2.65s/it]
100%|██████████| 10/10 [00:32<00:00,  3.25s/it]
100%|██████████| 10/10 [00:15<00:00,  1.58s/it]
100%|██████████| 10/10 [00:56<00:00,  5.63s/it]
100%|██████████| 10/10 [00:48<00:00,  4.81s/it]
Round 50, Train loss: 0.0055, Test Loss: 0.4322, Test Accuracy: 90.61%
Early stopping called at 50 epochs
"""

# %%
import re

# Log data as a string



# Regular expression to extract test accuracy
accuracy_pattern = r"Test Loss: (\d+\.\d+)"

# Find all matches in the log data
accuracies = re.findall(accuracy_pattern, log_data)

# Convert extracted accuracies to float
accuracies = [float(acc) for acc in accuracies]

# Print the extracted accuracies
print("Test Accuracies per Round:")
for i, acc in enumerate(accuracies, 1):
    print(f"Round {i}: {acc}%")

# If you need to plot the results
import matplotlib.pyplot as plt

rounds = list(range(1, len(accuracies) + 1))

plt.figure(figsize=(10, 6))
plt.plot(rounds, accuracies, marker='o', linestyle='-', color='b', label='Test Accuracy')
plt.title('Test Accuracy vs. Rounds')
plt.xlabel('Rounds')
plt.ylabel('Test Accuracy (%)')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Test Accuracies per Round:
# Round 1: 2.3772%
# Round 2: 2.1022%
# Round 3: 2.2624%
# Round 4: 1.8577%
# Round 5: 1.9236%
# Round 6: 1.5414%
# Round 7: 1.4819%
# Round 8: 1.0467%
# Round 9: 1.1574%
# Round 10: 0.918%
# Round 11: 0.76%
# Round 12: 0.6464%
# Round 13: 0.6281%
# Round 14: 0.5305%
# Round 15: 0.5616%
# Round 16: 0.5569%
# Round 17: 0.5422%
# Round 18: 0.4996%
# Round 19: 0.5049%
# Round 20: 0.4899%
# Round 21: 0.4745%
# Round 22: 0.4831%
# Round 23: 0.4889%
# Round 24: 0.4741%
# Round 25: 0.4638%
# Round 26: 0.4156%
# Round 27: 0.4124%
# Round 28: 0.4149%
# Round 29: 0.4119%
# Round 30: 0.4113%
# Round 31: 0.4149%
# Round 32: 0.4086%
# Round 33: 0.413%
# Round 34: 0.4133%
# Round 35: 0.4189%
# Round 36: 0.417%
# Round 37: 0.4144%
# Round 38: 0.4212%
# Round 39: 0.4195%
# Round 40: 0.4249%
# Round 41: 0.4286%
# Round 42: 0.4183%
# Round 43: 0.4208%
# Round 44: 0.4269%
# Round 45: 0.4264%
# Round 46: 0.4314%
# Round 47: 0.4367%
# Round 48: 0.4337%
# Round 49: 0.4375%
# ...

# %%
accuracies
# Out:
# [2.3772,
#  2.1022,
#  2.2624,
#  1.8577,
#  1.9236,
#  1.5414,
#  1.4819,
#  1.0467,
#  1.1574,
#  0.918,
#  0.76,
#  0.6464,
#  0.6281,
#  0.5305,
#  0.5616,
#  0.5569,
#  0.5422,
#  0.4996,
#  0.5049,
#  0.4899,
#  0.4745,
#  0.4831,
#  0.4889,
#  0.4741,
#  0.4638,
#  0.4156,
#  0.4124,
#  0.4149,
#  0.4119,
#  0.4113,
#  0.4149,
#  0.4086,
#  0.413,
#  0.4133,
#  0.4189,
#  0.417,
#  0.4144,
#  0.4212,
#  0.4195,
#  0.4249,
#  0.4286,
#  0.4183,
#  0.4208,
#  0.4269,
#  0.4264,
#  0.4314,
#  0.4367,
#  0.4337,
#  0.4375,
#  0.4322]
